# %% [markdown]
# Datatypes

# %%
name = "Python programming"
number = 34
decimal_number = 34.33

print(number)
print(name)
print(decimal_number)
# Out:
# 34
# Python programming
# 34.33

# %% [markdown]
# How to check datatype?

# %%
print(type(number))
print(type(name))
print(type(decimal_number))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
std_name = input("Enter your name : ")
print(f"The student name is {std_name}")
std_roll_number = input("Enter your roll number ")
print(f"{std_name} has {std_roll_number} roll number.")
# Out:
# The student name is zia
# zia has 2 roll number.

# %% [markdown]
# check the number is even or odd

# %%
num = int(input("Enter number "))
if num%2==0 :
    print(num,"is even")
else:
    print(num,"is odd")
# Out:
# 65 is odd
