# %% [markdown]
# # Python Loops
# - Python loops allow us to execute a statement or
# group of statements multiple times.
# Types of Loops in Python
# 1. For loop :
#     Excute a sequence of statments multiple times and abbreviates the code that manages the loop variable.
# 2. While loop :
#     Repeats a statment or group of statments while a given condition True .
# 3. Nested loop :
#     you can use one or more loop inside any another while , for loop.

# %% [markdown]
# # Python Loop control Statments
# - Break Statment
# - Continue statment
# - pass statment

# %% [markdown]
# # Python - For Loops
# - The for loop in Python provides the ability to loop over
# the items of any sequence, such as a list, tuple or a
# string.
# - This loop starts with the for keyword, followed by a
# variable that represents the current item in the sequence.
# - The in keyword links the variable to the sequence you
# want to iterate over.
# - A colon (:) is used at the end of the loop header, and the
# indented block of code beneath it is executed once for
# each item in the sequence.

# %%
# for iterating_variable in sequence:
#     statment(s)

s = """
Beautiful is better than ugly.
Explicit is better than implicit
Simple is better than complex 
Complex is better than complicated."""
# char chekc one by one letter in  s string 
for char in s : 
    #agar vowels letter ma sa koi bi char ka equal ho to osa ignore kr do 
    if char not in "aeiou":
        #baki letters ko print kr do 
        print(char , end=' ')
# Out:
#  B t f l   s   b t t r   t h n   g l y .
#  E x p l c t   s   b t t r   t h n   m p l c t
#  S m p l   s   b t t r   t h n   c m p l x
#  C m p l x   s   b t t r   t h n   c m p l c t d .
