# %% [markdown]
# # 4. User Input
# The input() function reads text from the user. Always returns a string, so convert to
# numbers when needed.
#
#
# Getting User Input

# %%
#input() used for getting input from user
name = input("Enter your name ")
#print() is used to show output to user
print(f"hellow {name}")
# Out:
# hellow Alice

# %% [markdown]
# ## Type casting
# Process of changing one dataype to another datatype/

# %% [markdown]
# # 5. Converiting Input to Number
#
# By default user input has string datatype . So when used enter numerical data it must change into integar

# %%
# if we not use typecasting 
number = input()
print(type(number))
# So we change string to integar
number = int(number)
print(type(number))
# Out:
# <class 'str'>
# <class 'int'>

# %%
age = int(input("Enter your age ."))
print(f"{name} has {age} years old .")
# Out:
# Alice has 30 years old .

# %% [markdown]
# ## Multiple Inputs

# %%
# use split() and map() for multiple values
x , y = map(int,input("Enter two numbers: ").split())
print(f"sum : {x + y}")
# Out:
# sum : 66
